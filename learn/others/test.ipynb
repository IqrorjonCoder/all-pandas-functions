# %%
import pandas as pd

pd.test('--skip-slow')
# Out:
# . [  0%]
# .............ssssssssssssss............................                  [  0%]
# ../../venv/lib/python3.8/site-packages/pandas/tests/test_take.py ....... [  0%]
# ........................................................................ [  0%]
# ..                                                                       [  0%]
# ../../venv/lib/python3.8/site-packages/pandas/tests/api/test_api.py .... [  0%]
# .......                                                                  [  0%]
# ../../venv/lib/python3.8/site-packages/pandas/tests/api/test_types.py .. [  0%]
#                                                                          [  0%]
# ../../venv/lib/python3.8/site-packages/pandas/tests/apply/test_frame_apply.py . [  0%]
# ........................................................................ [  0%]
# ........................................................................ [  0%]
# ...
